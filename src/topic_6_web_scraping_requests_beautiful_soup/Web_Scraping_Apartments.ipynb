# %% [markdown]
# # Web Scraping
#
# Web scraping, web harvesting, or web data extraction is data scraping used for extracting data from websites. Web scraping software may access the World Wide Web directly using HTTP or through a browser.
#
# ![Robots](https://upload.wikimedia.org/wikipedia/commons/6/63/Web_Robots_Logo.png)
#
# ## How the scraping process works
# * request the URL (uniform resource locator / web address)
# * parse the response text
# * find required HTML elements and their content
# * save the results in the format you need
#
# ## Scraping responsibly
# * Check for other ways of accessing data (JSON API, CSV download, etc.).
# * Play nice: do not overload sites with requests.
# * Access publicly available data only.
# * Respect robots.txt.
# * Remember the difference between scraping something and how you use it (publishing, monetizing, etc.).
#
# ### Legality note
# As of Sep 2019 the direction is that it should be legal to scrape publicly available data provided you do not disturb the normal operation of the website. See https://www.eff.org/deeplinks/2019/09/victory-ruling-hiq-v-linkedin-protects-scraping-public-data.

# %% [markdown]
# ## HTML and HTTP fundamentals
# * https://developer.mozilla.org/en-US/docs/Web/HTML
# * https://developer.mozilla.org/en-US/docs/Learn/HTML/Introduction_to_HTML/Getting_started
# * https://developer.mozilla.org/en-US/docs/Web/HTTP/Overview
# * Chrome DevTools: https://developers.google.com/web/tools/chrome-devtools/open
# * Safari DevTools: https://developer.apple.com/safari/tools/
#
# Understanding both is essential for scraping: HTML tells you which tags and attributes hold the data you want, while HTTP defines how you request pages, handle status codes, respect robots.txt, and throttle or paginate responsibly.

# %% [markdown]
# ## Scraping tables with pandas
# Pandas data analysis has basic web scraping capabilities via `pandas.read_html`. It works when a page exposes data in `<table>` elements, automatically returning each table as a dataframe. If the data is not in tabular form, use BeautifulSoup or Scrapy instead (see the separate BeautifulSoup notebook).

# %%
from datetime import datetime
import sys
import pandas as pd

print(f"Date: {datetime.now()}")
print(f"Python version: {sys.version}")
print(f"pandas version: {pd.__version__}")
# Out:
# Date: 2026-01-27 16:32:47.845652
# Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# pandas version: 2.2.2

# %% [markdown]
# ## Choose a target URL
# The example below scrapes flat listings. Notice how query parameters in the URL describe the target area. Adjust the URL to match the data you want.

# %%
# url = "https://www.ss.com/en/real-estate/flats/riga/centre/sell/"
# url = "https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/"  # renting
# url = "https://www.ss.com/en/real-estate/flats/riga/agenskalns/sell/"
url = "https://www.ss.com/en/real-estate/flats/riga/chiekurkalns/hand_over/"
print(f"URL: {url}")
# Out:
# URL: https://www.ss.com/en/real-estate/flats/riga/chiekurkalns/hand_over/

# %% [markdown]
# ## Read HTML tables into dataframes
# `pandas.read_html` downloads the page, parses all HTML tables, and returns a list. Some sites (like ss.com) use tables for layout, so expect more than one table and pick the one that holds the data you need.

# %%
dfs = pd.read_html(url, header=0) # we read ALL the tables on the page # here we make a https request to particular web page
print(f"Found {len(dfs)} tables (type: {type(dfs).__name__})")

if len(dfs) <= 4:
    raise ValueError("Expected at least 5 tables on the page to access index 4.")

# MDN docs on table element: https://developer.mozilla.org/en-US/docs/Web/HTML/Reference/Elements/table

df = dfs[4]  # the 5th table on the page holds the listings
# in more modern pages this would usually be index 0 (that is 1st and only table in the page)
display(df.head())
# Out:
# Found 6 tables (type: list)
#    Advertisements \tdate  Advertisements \tdate.1  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
#                              Advertisements \tdate.2                Street  \
# 0  Tiek izīrēts divu istabu dzīvoklis Čiekurkalnā...  Chiekurkalna 2. cr..
# 1  Īpašnieks, jaunbūvētā mājā, Rīga, Čiekurkalna ...  Chiekurkalna 4. cr..
# 2  Хозяин сдаёт со всей мебелью, техникой, бойлер...  Chiekurkalna 1. cr..
# 3  Ilgtermiņa īrei tiek piedāvāts gaišs un mājīgs...              Rusova 9
# 4  Izīrē vienistabas dzīvokli Čiekurkalnā, 32 m²....  Chiekurkalna 1. l...
#
#    R.  m² Floor         Series Price, m2       Price
# 0   2  61   3/5            New    7.05 €  430 €/mon.
# 1   2  70   4/5            New       9 €  630 €/mon.
# ...

# %%
# let's show how many rows are in those tables
for dataframe in dfs:
    print(f"Shape: {dataframe.shape}")

# so we need the dataframe from our list of dataframes with index 4 (the 5th table)
# Out:
# Shape: (0, 1)
# Shape: (0, 1)
# Shape: (0, 2)
# Shape: (0, 5)
# Shape: (18, 10)
# Shape: (3, 3)

# %% [markdown]
# ## Inspect the scraped table
# Always check the shape and a sample of the data before exporting.

# %%
print(f"Shape: {df.shape}")
df.head()
# Out:
# Shape: (18, 10)
#    Advertisements \tdate  Advertisements \tdate.1  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
#                              Advertisements \tdate.2                Street  \
# 0  Tiek izīrēts divu istabu dzīvoklis Čiekurkalnā...  Chiekurkalna 2. cr..
# 1  Īpašnieks, jaunbūvētā mājā, Rīga, Čiekurkalna ...  Chiekurkalna 4. cr..
# 2  Хозяин сдаёт со всей мебелью, техникой, бойлер...  Chiekurkalna 1. cr..
# 3  Ilgtermiņa īrei tiek piedāvāts gaišs un mājīgs...              Rusova 9
# 4  Izīrē vienistabas dzīvokli Čiekurkalnā, 32 m²....  Chiekurkalna 1. l...
#
#    R.  m² Floor         Series Price, m2       Price
# 0   2  61   3/5            New    7.05 €  430 €/mon.
# 1   2  70   4/5            New       9 €  630 €/mon.
# ...

# %% [markdown]
# ## Save the results
# Dataframes can be saved to many formats. Use `index=False` when you do not want the dataframe index written out.

# %%
# df.to_json("agenskalns.json", orient="records", index=False)
# df.to_csv("agenskalns.csv", index=False)
# df.to_excel("agenskalns.xlsx", index=False)
df.to_csv("chiekurkalns.csv", index=False)
df.to_excel("chiekurkalns.xlsx", index=False)

# %%
# we can download this locall from google colab
import google.colab.files as files
files.download('chiekurkalns.xlsx')

# %%
# let's go back to agenskalns as it has more than 30 ads so we can see the pagination in action
url1 = "https://www.ss.com/en/real-estate/flats/riga/agenskalns/hand_over/"
# let us get agenskalns
print(f"URL: {url1}")
dfs_page1 = pd.read_html(url1, header=0) # this is where web scraping actually occurs
# again index 4
if len(dfs_page1) <= 4:
    raise ValueError("Expected at least 5 tables on the first page to access")
df = dfs_page1[4] # we overwrite the ciekurkalns dataframe with our agenskalns
print(f"Shape: {df.shape}") # for more popular page we expect 30 rows
df.head()
# Out:
# URL: https://www.ss.com/en/real-estate/flats/riga/agenskalns/hand_over/
# Shape: (30, 10)
#    Advertisements \tdate  Advertisements \tdate.1  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
#                              Advertisements \tdate.2        Street  R.    m²  \
# 0  Renovētā ēkā tiek izīrēts divistabu dzīvoklis ...     Alises 2C   2    57
# 1  Izrīrē 2-istabu dzīvokli Āgenskalnā. Ļoti ērta...   Kristapa 24   2  4670
# 2  Uz ilgu laiku, vismaz 1 gadu tiek izīrēts eksk...   Ranka d. 34   3    93
# 3  Bez komisijas maksas, ilgtermiņā izīrējam 2 is...  Lielirbes 13   2    68
# 4  4 istabu dzīvoklis. Bez komisijas maksas. Izīr...  Lielirbes 13   4   125
#
#    Floor    Series Price, m2         Price
# 0    2/2    Recon.   14.91 €    850 €/mon.
# ...

# %% [markdown]
# ## Combine multiple pages
# You can scrape additional pages (e.g., pagination) and concatenate them. Here we fetch a second page, grab its listings table, and stack the data.

# %%
url2 = "https://www.ss.com/en/real-estate/flats/riga/agenskalns/sell/page2.html"
print(f"URL: {url2}")

dfs_page2 = pd.read_html(url2, header=0)
if len(dfs_page2) <= 4:
    raise ValueError("Expected at least 5 tables on the second page to access index 4.")

df_page2 = dfs_page2[4]

# now that we have two very similar dataframes with same columns
combined = pd.concat([df, df_page2], ignore_index=True)
print(f"Combined shape: {combined.shape}")
combined.head()
# Out:
# URL: https://www.ss.com/en/real-estate/flats/riga/agenskalns/sell/page2.html
# Combined shape: (60, 10)
#    Advertisements \tdate  Advertisements \tdate.1  \
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
#
#                              Advertisements \tdate.2        Street  R.    m²  \
# 0  Renovētā ēkā tiek izīrēts divistabu dzīvoklis ...     Alises 2C   2    57
# 1  Izrīrē 2-istabu dzīvokli Āgenskalnā. Ļoti ērta...   Kristapa 24   2  4670
# 2  Uz ilgu laiku, vismaz 1 gadu tiek izīrēts eksk...   Ranka d. 34   3    93
# 3  Bez komisijas maksas, ilgtermiņā izīrējam 2 is...  Lielirbes 13   2    68
# 4  4 istabu dzīvoklis. Bez komisijas maksas. Izīr...  Lielirbes 13   4   125
#
#    Floor    Series Price, m2         Price
# 0    2/2    Recon.   14.91 €    850 €/mon.
# ...

# %% [markdown]
# ## Save combined data
# Export the merged dataframe for downstream analysis.

# %%
combined.to_excel("agenskalns_big.xlsx", index=False)
combined.to_csv("agenskalns_big.csv", index=False)

# %%
# we could also download this to our computer from colab using download tools offered by Google
import google.colab.files as files
files.download('agenskalns_big.xlsx')

# %% [markdown]
# ## Where to go next
# * Loop through pages until you detect the last one automatically.
# * Extract detail-page links from each row with BeautifulSoup to enrich the dataset.
# * Respect the target site's terms of service and throttle requests.

# %% [markdown]
# # Web Scraping with Beautiful Soup
#
# ## Introduction
#
# As we now know, web scraping is a technique to automatically access and extract large amounts of information from a website, which can save a huge amount of time and effort.
#
# ## Beautiful Soup
#
# Beautiful Soup is a Python library for pulling data out of HTML and XML files. It creates a parse tree from page source code that can be used to extract data easily. It is a powerful library and very easy to use.

# %%
from datetime import datetime
print(f"Hello, scrapers {datetime.now()}")
import sys
print(f"Python version: {sys.version}")

#  Requests for handling HTTP get and other requests
try:
    import requests # this is external library but offered by Google Colab
    # print version
    print(f"Requests version: {requests.__version__}")
except ImportError:
    print("requests is not installed")
    print("Install it with pip install requests")

# requests is external library
# if you used Python locally you would need to install it with pip install requests
import time # import for playing nice and not getting blocked

import pandas as pd # for data analysis - more on pandas will be in other lecture
from datetime import datetime # standard library for date and time
# from BeautifulSoup4 import BeatifulSoup if installed through pip install BeautifulSoup4
#
try:
    from bs4 import BeautifulSoup # again external library but offered as standard by Google Colab
    from bs4 import __version__ as bs4_version
    # print version
    print(f"BeautifulSoup version: {bs4_version}")
    # print(f"BeautifulSoup version: {BeautifulSoup.__version__}")
except ImportError:
    print("BeautifulSoup is not installed")
    print("Install it with pip install BeautifulSoup4")
# from bs4 import BeautifulSoup # an external library for parsing HTML (and XML) content
# bs4 is external library as well

# all of the above should be available on Google Colab as well as your local machine
# Out:
# Hello, scrapers 2026-01-27 17:03:20.143339
# Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Requests version: 2.32.4
# BeautifulSoup version: 4.13.5

# %%
# !pip install beautifulsoup4
# if bs4 not found install it with

# https://www.crummy.com/software/BeautifulSoup/

# %%
# first we get the url we want to scrape
# centrs = "https://www.ss.com/lv/real-estate/flats/riga/centre/sell/"
centrs = "https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/"
# centrs = "https://www.ss.com/en/real-estate/flats/riga/centre/sell/"
# centrs
# agenskalns = "https://www.ss.com/en/real-estate/flats/riga/agenskalns/sell/"

# url = agenskalns # just an alias
url = centrs # just an alias for the same string
print(f"URL: {url}")
# Out:
# URL: https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/

# %%
# here we make a something called HTTP GET request to the url in centrs
# so very similar to what the browser does
print(f"Requesting URL: {url}")
response = requests.get(url) # here we make a request to the url in centrs, and store the response in req
print(f"Response code: {response.status_code}")
# so where we could use our status_code to check if our request went through sucessfully
# so 200 is the ALL OK code in HTTP, many 4xx and 5xxx failure codes
# you could add an if statement and handle errors if needed here
# Out:
# Requesting URL: https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/
# Response code: 200

# %%
# list of HTTP response codes
# https://en.wikipedia.org/wiki/List_of_HTTP_status_codes

# %% [markdown]
# ## Seeing text of the response
#
# The text of the response will be HTML, which is a markup language that is used to create web pages. Let's see the text of the response.

# %%
# so now we can start working with the response without making additional requests
print(f"We have {len(response.text)} characters in the response")
response.text[:300] # first 300 text characters
# Out:
# We have 53063 characters in the response
# '<!DOCTYPE html>\r\n<HTML lang="en"><HEAD>\r\n<title>SS.COM Flats - Riga - Centre, Prices, Hand over - Advertisements</title>\r\n<meta http-equiv="Content-Type" CONTENT="text/html; charset=UTF-8">\r\n<meta name="viewport" content="user-scalable=1, width=device-width, initial-scale=1.0"/>\r\n<meta name="keyword'

# %%
# we could attempt to parse the text with the standard library, but it is not very time consuming
# basically a "fool's errand" - because we have better tools for the job - BeautifulSoup
"Agensk" in response.text
# Out:
# True

# %%
response.text.index("Elizab") # I am looking for text Eliz in the response text
# Out:
# 14172

# %%
my_index = response.text.index("Elizab")
# So Eliz needle is at
my_index
# Out:
# 14172

# %%
# i could us slicing to see the concordance
window_size = 150
response.text[my_index-window_size:my_index+window_size] # getting some text around what I was looking forb
# Out:
# '">Duntes</option><option value="4161">Dzirnavu</option><option value="4175">Eksporta</option><option value="4178">Elijas</option><option value="4179">Elizabetes</option><option value="4199">Eveles</option><option value="4225">Ganibu d.</option><option value="4281">Gertrudes</option><option value="42'

# %%
# we could actually get the whole table with pandas library
# this approach requires that data on the web page exists within <table> ..... </table> tags

# %%
# we could manually use text searching tools to work on the whole text of html but it would not convenient
# many other people have already written tools to parse/structure this text

# %% [markdown]
# ## Using Beautiful Soup for parsing HTML

# %%
# parser means structuring your text into some data structure
# we pass the text of the response to the parser
soup = BeautifulSoup(response.text, 'lxml') # lxml is improved parser, a little bit more lenient towards badly structured HTML
# you could also use default parser with command
# soup = BeautifulSoup(req.text) - but it is slower and less lenient
# soup = BeautifulSoup(req.text)
# note this process does not require internet connection, it is just parsing the text
# the internet connection was only needed to get the response first
soup.title
# Out:
# <title>SS.COM Flats - Riga - Centre, Prices, Hand over - Advertisements</title>

# %%
type(soup)  # so we have soup object which contains all the information about the page in a structured manner
# of course you could use another name for the object, but soup is a convention
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ## Finding element which contains last page number
#
# We know it is an anchor element with some atrributes. Let's find it.

# %%
# we could use find_all method to find all anchor elements
# anchor elements are links
anchors = soup.find_all("a") # so we are looking for all <a> elements in the page
print(f"Found {len(anchors)} anchor elements")
# Out:
# Found 99 anchor elements

# %%
# more about anchors in MDN page: https://developer.mozilla.org/en-US/docs/Web/HTML/Reference/Elements/a

# %%
# well 96 is a big number we could see if we could filter them out
# in this case we know our anchor has specific attribute rel="prev" so we could filter them out
# in this case I will use find method which finds first matching element
last_page_anchor = soup.find("a", {"rel": "prev"}) # so we are looking for all <a> elements with attribute rel="prev"
# note how we passed in dictionary to specify the attribute or attributes we are looking for
# you can look for any number of attributes here with particular values
last_page_anchor # if I got None that means our filter was too strict (maybe the attribute does not exist or value of it)
# Out:
# <a class="navi" href="/en/real-estate/flats/riga/centre/hand_over/page24.html" name="nav_id" rel="prev"><img border="0" height="5" src="https://i.ss.com/img/s_left.png" style="padding-bottom:2px;" width="9"/> Previous</a>

# %%
# let's get href attribute of the anchor
last_page_href = last_page_anchor.get("href") # so this get is like getting a value from a dictionary
print(f"Last page href: {last_page_href}") # so now I have a string of the URL
# Out:
# Last page href: /en/real-estate/flats/riga/centre/hand_over/page24.html

# %%
# now let's get the number of the last page we could use regular expression but here we will use string manipulation
# we will split the string by / and get the last element
first_part = last_page_href.split("page")[0] # so we are splitting the string by page and getting the first element
# instead of page I could have used / or something else, but page here was most appropriate
print(f"First part: {first_part}") # we do not need it just showing it for learning
last_part = last_page_href.split("page")[-1] # so we are splitting the string by page and getting the second to last element

print(f"Last part: {last_part}")
# Out:
# First part: /en/real-estate/flats/riga/centre/hand_over/
# Last part: 24.html

# %%
# now we can split by dot and get the number_str
number_str = last_part.split(".")[0] # so we are splitting the string by . and getting the first element
print(f"Number string: {number_str}")
type(number_str)
# Out:
# Number string: 24
# str

# %%
# now we just need to convert to integer
last_page_number = int(number_str) # so we are converting string to integer
print(f"Last page number: {last_page_number}")
type(last_page_number)
# Out:
# Last page number: 24
# int

# %%
url
# Out:
# 'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/'

# %%
# now we need to create a function that takes a url and returns a list of all urls including he original one
# so we will create a function that takes a url and returns a list of urls
def get_urls(url):
    # get response
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to get response from {url}")
        return [] # means we failed to have a good response
    print(f"Successfully got response from {url}")
    # create soup
    soup = BeautifulSoup(response.text, 'lxml')
    # find anchor with rel=prev
    last_page_anchor = soup.find("a", {"rel": "prev"})
    # check if it is not None
    if last_page_anchor is None:
        return [url] # means there are no more pages, means we just need one page but to keep consistency we return a list of ONE element - the list of original URL
    # get href
    last_page_href = last_page_anchor.get("href")
    # get last part
    last_part = last_page_href.split("page")[-1]
    # get number string
    number_str = last_part.split(".")[0]
    # get last page number
    last_page_number = int(number_str)
    # now we can build the full list of urls
    urls = [url] # we start with the original url
    for i in range(2, last_page_number+1): # + 1 because we want the last page included
        urls.append(f"{url}page{i}.html") # note our url includes / at the end

    return urls

# let's test our function
# we will test it on the first page of agenskalns
urls = get_urls(url)
print(f"URLs: {urls}")
# Out:
# Successfully got response from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/
# ...

# %% [markdown]
# ## Extracting data from HTML tables using Beautiful Soup
#
# Now that we have a list of URLs where information is to be found, we want to actually learn how to get detailed data from the tables in those pages.

# %%
# we could now use pandas to loop through all the urls and get the tables
# however we want to get the actual links to the ads so we will continue using BeautifulSoup

# %%
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/#find-all
tables = soup.find_all("table") # finds ALL elements matching our filter
len(tables) # it will be a list of some length, possibly 0 if we did not find any elements
# Out:
# 6

# %% [markdown]
# ## Finding Headline from Table Row element

# %%
# Now we want to find what our column names should be no matter the type of ad
# tr stands for table row
# mdn tr documentation
# https://developer.mozilla.org/en-US/docs/Web/HTML/Element/tr

# %%
# find finds just one(first) match
headline = soup.find("tr", {"id":"head_line"}) # this is a shorter way of finding by tr AND this element having particular id
# id attribute in proper HTML should be unique that helps a TON for focus
headline
# Out:
# <tr id="head_line">
# <td class="msg_column" colspan="3" width="70%">
# <span style="float:left;"> Advertisements
# </span>
# <span align="right" class="msg_column" style="float:right;text-align:right;padding-right:3px;">
# <noindex>
# <a class="a19" href="/en/real-estate/flats/riga/centre/hand_over/fDgSeF4S.html" rel="nofollow">date</a></noindex></span>
# </td>
# ...

# %%
type(headline)
# Out:
# bs4.element.Tag

# %%
# next we can search through the headling table row element and find individual table data elements
headtds = headline.find_all("td") #note I am looking through not ALL soup object but just the headline element
# https://developer.mozilla.org/en-US/docs/Web/HTML/Element/td
headtds  # a list of td elements
# Out:
# [<td class="msg_column" colspan="3" width="70%">
#  <span style="float:left;"> Advertisements
#  </span>
#  <span align="right" class="msg_column" style="float:right;text-align:right;padding-right:3px;">
#  <noindex>
#  <a class="a19" href="/en/real-estate/flats/riga/centre/hand_over/fDgSeF4S.html" rel="nofollow">date</a></noindex></span>
#  </td>,
#  <td class="msg_column_td" nowrap=""><noindex><a class="a18" href="/en/real-estate/flats/riga/centre/hand_over/fDgSeF4SFDwT.html" rel="nofollow" title="">Street</a></noindex></td>,
#  <td class="msg_column_td" nowrap=""><noindex><a class="a18" href="/en/real-estate/flats/riga/centre/hand_over/fDgSeF4SelM=.html" rel="nofollow" title="">R.</a></noindex></td>,
#  <td class="msg_column_td" nowrap=""><noindex><a class="a18" href="/en/real-estate/flats/riga/centre/hand_over/fDgSeF4QelM=.html" rel="nofollow" title="">m²</a></noindex></td>,
# ...

# %%
len(headtds) # so we have some of lements (could be 8, 10 depends on the type of ad)
# Out:
# 8

# %%
headline.text # the text is extracted from children, grandchildren, greatgrandchildren elements and so on
# Out:
# '\n\n\xa0Advertisements\n\n\n\ndate\n\nStreetR.m²FloorSeriesPrice, m2Price'

# %%
headtds[3].text  # so text of 4th child of headline (which is tr with id headline) element
# Out:
# 'm²'

# %%
# text of last td
headtds[-1].text # should be price
# Out:
# 'Price'

# %%
# so we do not want announcements and data so we will skip the first TD with headtds[1:]
headcolumns = [el.text for el in headtds[1:]] #.text gets us content even from children and grandchildren
#  I used so called list comprehension to creat a new list
headcolumns
# Out:
# ['Street', 'R.', 'm²', 'Floor', 'Series', 'Price, m2', 'Price']

# %%
also_headline_columns = [] # empty list
for el in headtds[1:]: # so I loop through all td elements starting from 2nd element(with index 1 not 0)
    also_headline_columns.append(el.text)
also_headline_columns
# Out:
# ['Street', 'R.', 'm²', 'Floor', 'Series', 'Price, m2', 'Price']

# %%
# lets combine the above cells into a function which will always get us columns
def getColList(soup, default_columns = ("description","url")):
    column_list = list(default_columns) # we decided to that we need these two column names no matter the html
    headline = soup.find("tr", {"id":"head_line"})
    headtds = headline.find_all("td")
    headcolumns = [el.text for el in headtds[1:]] # this will get all column names starting with 2nd in HTML
    column_list += headcolumns # we add the head columns to our initial column list
    return column_list

# %%
# now that I have a function I can use it on any soup object
column_names = getColList(soup)
column_names # so this should work no matter what type of SS.com page the soup is made of
# Out:
# ['description',
#  'url',
#  'Street',
#  'R.',
#  'm²',
#  'Floor',
#  'Series',
#  'Price, m2',
#  'Price']

# %% [markdown]
# ## Finding Table Rows of Actual Data
#
# Now that we have found a way to get text for table heading cells, let's actually get the advertisements.

# %%
trows = soup.find_all('tr')  # so i want all table rows on the page
print(f"Got {len(trows)} table rows") # i get more than 30 rows, so I need to filter them
# Out:
# Got 39 table rows

# %%
print(trows[5]) # our first ad so from trows[5] to trows[34 would work as well]
# Out:
# <tr id="tr_57271512"><td class="msga2 pp0"><input id="c57271512" name="mid[]" type="checkbox" value="57271512_1106_0"/></td><td class="msga2"><a href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="im57271512"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364075/72814873.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JUExJTlBdnQlQTclOEQlOTUlRUElQTElOUR1dyVBMiU4OSU5OCVBNCVBOSU5N3h2JUE3JTg1JTk4JTlFJUEwJTk2|pfBBrUdn" href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="dm_57271512">Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Avotu 23A</td><td c="1" class="msga2-o pp6" nowrap="">2</td><td c="1" class="msga2-o pp6" nowrap="">52</td><td c="1" class="msga2-o pp6" nowrap="">2/2</td><td c="1" class="msga2-o pp6" nowrap="">Pre-war house</td><td c="1" class="msga2-o pp6" nowrap="">10.58 €</td><td c="1" class="msga2-o pp6" nowrap="">550  €/mon.</td></tr>

# %%
print(trows[4]) # this is our headline row which we got earlier using particular id="head_line" attribute
# Out:
# <tr id="head_line">
# <td class="msg_column" colspan="3" width="70%">
# <span style="float:left;"> Advertisements
# </span>
# <span align="right" class="msg_column" style="float:right;text-align:right;padding-right:3px;">
# <noindex>
# <a class="a19" href="/en/real-estate/flats/riga/centre/hand_over/fDgSeF4S.html" rel="nofollow">date</a></noindex></span>
# </td>
# ...

# %%
# less flexible solution would be to hard code this
all_ads = trows[5:35] # so starting from 6th element to 35th element
all_ads[-1] # last one - 35
# Out:
# <tr id="tr_57285082"><td class="msga2 pp0"><input id="c57285082" name="mid[]" type="checkbox" value="57285082_1106_0"/></td><td class="msga2"><a href="/msg/en/real-estate/flats/riga/centre/bhdhp.html" id="im57285082"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364063/72812402.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JUFBb3glQTIlQUQlQjJkbiVBNXB2JUE1JUE4ZmdqJUFDbXYlQTAlQTVmY2c=|s9Dpt637" href="/msg/en/real-estate/flats/riga/centre/bhdhp.html" id="dm_57285082">Сдается уютная, солнечная квартира в новом проекте "Duntes Ozoli</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Duntes 28</td><td c="1" class="msga2-o pp6" nowrap="">2</td><td c="1" class="msga2-o pp6" nowrap="">65</td><td c="1" class="msga2-o pp6" nowrap="">6/15</td><td c="1" class="msga2-o pp6" nowrap="">New</td><td c="1" class="msga2-o pp6" nowrap="">8.46 €</td><td c="1" class="msga2-o pp6" nowrap="">550  €/mon.</td></tr>

# %%
# if i had no other choices I could find starting and end index by hand and hard code it
# but that is liable to change between pages

# %%
# we could filter elements using standard loop
apt_row_elements = [] # so start with empty list
for row in trows: # trows is all table rows in our page which we want to filter
  # let's try to get id for row
  id = row.get('id',"") # elements MIGHT NOT HAVE an ID!
  # get('id',"") means I ask for id and if one not found i get empty string
  # so I can use string methods on empty string
  # print(id) #
  # so we want all rows whose id starts with "tr_" but does not contain "bnr" in them - "bnr" is some banner row which is not what we need
  if id.startswith("tr_") and not id.startswith("tr_bnr"):
    apt_row_elements.append(row) # so we add that row which matches our requirement to the list

len(apt_row_elements)
# Out:
# 30

# %%
# hardest part in this
# how to filter only specific rows
# we need to find something that is unique to our apartment rows but not to the extra rows
# remember we id is not guaranteed, so "" gives us default value when there is no id
# because it is possible there is no id atrribute at all
# sometimes there were unusable rows with tr_bnr attribute
# in this recipe you would change the startswith to whatever you need in your case
# and not row.get('id',"").startswith("tr_bnr") is not needed anymore but left for legacy reasons
apt_rows = [row for row in trows if row.get('id',"").startswith("tr_") and not row.get('id',"").startswith("tr_bnr") ] # so we use more compact list comprehension
# note the use of get method to get the value of the id attribute
# table rows are not guaranteed to have id attribute
# so we use the trick of getting the value of the attribute or empty string if it does not exist
# some pages have this fake tr with id tr_bnr element which are not ads
# you could have used a regular loop based solution but this one liner is more elegant
len(apt_rows)
# Out:
# 30

# %%
apt_rows[-1]
# Out:
# <tr id="tr_57285082"><td class="msga2 pp0"><input id="c57285082" name="mid[]" type="checkbox" value="57285082_1106_0"/></td><td class="msga2"><a href="/msg/en/real-estate/flats/riga/centre/bhdhp.html" id="im57285082"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364063/72812402.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JUFBb3glQTIlQUQlQjJkbiVBNXB2JUE1JUE4ZmdqJUFDbXYlQTAlQTVmY2c=|s9Dpt637" href="/msg/en/real-estate/flats/riga/centre/bhdhp.html" id="dm_57285082">Сдается уютная, солнечная квартира в новом проекте "Duntes Ozoli</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Duntes 28</td><td c="1" class="msga2-o pp6" nowrap="">2</td><td c="1" class="msga2-o pp6" nowrap="">65</td><td c="1" class="msga2-o pp6" nowrap="">6/15</td><td c="1" class="msga2-o pp6" nowrap="">New</td><td c="1" class="msga2-o pp6" nowrap="">8.46 €</td><td c="1" class="msga2-o pp6" nowrap="">550  €/mon.</td></tr>

# %%
apt_rows[0]
# Out:
# <tr id="tr_57271512"><td class="msga2 pp0"><input id="c57271512" name="mid[]" type="checkbox" value="57271512_1106_0"/></td><td class="msga2"><a href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="im57271512"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364075/72814873.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JUExJTlBdnQlQTclOEQlOTUlRUElQTElOUR1dyVBMiU4OSU5OCVBNCVBOSU5N3h2JUE3JTg1JTk4JTlFJUEwJTk2|pfBBrUdn" href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="dm_57271512">Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Avotu 23A</td><td c="1" class="msga2-o pp6" nowrap="">2</td><td c="1" class="msga2-o pp6" nowrap="">52</td><td c="1" class="msga2-o pp6" nowrap="">2/2</td><td c="1" class="msga2-o pp6" nowrap="">Pre-war house</td><td c="1" class="msga2-o pp6" nowrap="">10.58 €</td><td c="1" class="msga2-o pp6" nowrap="">550  €/mon.</td></tr>

# %%
# lets make a function from the above doodle and make it work on most pages on SS
def getRowList(soup):
    trows = soup.find_all('tr')
    # then we filter out specific rows in this case all ads start with tr_ but not with tr_bnr
    aprows = [row for row in trows if row.get('id',"").startswith("tr_") and not row.get('id',"").startswith("tr_bnr") ]
    return aprows

# check if it works
rows = getRowList(soup)
print(f"Got {len(rows)} rows")
# Out:
# Got 30 rows

# %%
# we are going to check the first ad
first_ad = apt_rows[0]
first_ad
# Out:
# <tr id="tr_57271512"><td class="msga2 pp0"><input id="c57271512" name="mid[]" type="checkbox" value="57271512_1106_0"/></td><td class="msga2"><a href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="im57271512"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364075/72814873.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JUExJTlBdnQlQTclOEQlOTUlRUElQTElOUR1dyVBMiU4OSU5OCVBNCVBOSU5N3h2JUE3JTg1JTk4JTlFJUEwJTk2|pfBBrUdn" href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="dm_57271512">Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Avotu 23A</td><td c="1" class="msga2-o pp6" nowrap="">2</td><td c="1" class="msga2-o pp6" nowrap="">52</td><td c="1" class="msga2-o pp6" nowrap="">2/2</td><td c="1" class="msga2-o pp6" nowrap="">Pre-war house</td><td c="1" class="msga2-o pp6" nowrap="">10.58 €</td><td c="1" class="msga2-o pp6" nowrap="">550  €/mon.</td></tr>

# %%
# we are going to check the first ad
row_tds = first_ad.find_all('td') # get all table data elements from first ad/row
len(row_tds)
# Out:
# 10

# %%
row_tds # so we have a list of individual table data cells
# Out:
# [<td class="msga2 pp0"><input id="c57271512" name="mid[]" type="checkbox" value="57271512_1106_0"/></td>,
#  <td class="msga2"><a href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="im57271512"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364075/72814873.th2.jpg"/></a></td>,
#  <td class="msg2"><div class="d1"><a class="am" data="JUExJTlBdnQlQTclOEQlOTUlRUElQTElOUR1dyVBMiU4OSU5OCVBNCVBOSU5N3h2JUE3JTg1JTk4JTlFJUEwJTk2|pfBBrUdn" href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="dm_57271512">Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo</a></div></td>,
#  <td c="1" class="msga2-o pp6" nowrap="">Avotu 23A</td>,
#  <td c="1" class="msga2-o pp6" nowrap="">2</td>,
#  <td c="1" class="msga2-o pp6" nowrap="">52</td>,
#  <td c="1" class="msga2-o pp6" nowrap="">2/2</td>,
#  <td c="1" class="msga2-o pp6" nowrap="">Pre-war house</td>,
#  <td c="1" class="msga2-o pp6" nowrap="">10.58 €</td>,
# ...

# %%
# this is the checkbox we want nothing from that
row_tds[0].text
# Out:
# ''

# %%
# second is the image table data cell
row_tds[1].text
# Out:
# ''

# %%
row_tds[1].attrs
# Out:
# {'class': ['msga2']}

# %%
img = row_tds[1].find("img")
img
# Out:
# <img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364075/72814873.th2.jpg"/>

# %%
img.get("src")
# Out:
# 'https://i.ss.com/gallery/8/1457/364075/72814873.th2.jpg'

# %%
row_tds[2].text
# Out:
# 'Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo'

# %%
# last one should be price
row_tds[-1].text # notice this might need some cleaning to convert to number
# Out:
# '550  €/mon.'

# %%
# so second table data cell (which has alos has image) has anchor
a = row_tds[1].find('a') # a tag is called anchor tag, here we find first (there is only one anchor in this td)
a
# Out:
# <a href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="im57271512"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364075/72814873.th2.jpg"/></a>

# %%
a.attrs  # so i can read attributes as a dictionary
# Out:
# {'href': '/msg/en/real-estate/flats/riga/centre/bdimo.html',
#  'id': 'im57271512'}

# %%
a.get('href'), a['href'] # two ways of accesing this attribute, second will raise KeyError if attribute not found
# so all we need is to add http://www.ss.com in front
# Out:
# ('/msg/en/real-estate/flats/riga/centre/bdimo.html',
#  '/msg/en/real-estate/flats/riga/centre/bdimo.html')

# %%
# let's add https://www.ss.com in front
prefix = "https://www.ss.com" # should work also for www.ss.lv
# now we simply concatenate the two strings together for our full url
full_url = prefix + a.get('href')
print(f"Full URL: {full_url}")
# Out:
# Full URL: https://www.ss.com/msg/en/real-estate/flats/riga/centre/bdimo.html

# %%
column_names
# Out:
# ['description',
#  'url',
#  'Street',
#  'R.',
#  'm²',
#  'Floor',
#  'Series',
#  'Price, m2',
#  'Price']

# %%
# let's print text from row_tds list from td with index 2 (3rd one) until end
for td in row_tds[2:]:
    print(td.text)
# Out:
# Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo
# Avotu 23A
# 2
# 52
# 2/2
# Pre-war house
# 10.58 €
# 550  €/mon.

# %%
# combining all of the above work into a function
def getRow(row,colist=column_names):
    """
    row is a soup object representing a row of the table - tr element
    inside row should be some table data elements which we will extract
    along with the url and description
    colist is a list of column names
    """
    row_tds = row.find_all('td')  # find all table data elements
    rowDict = {} # we will store our data in a dictionary, so we can easily convert it to dataframe
    if len(row_tds) < 3: # a little sanity check, if we have less than 3 table data elements we will skip this row
        print("Hmm bad row")
        return rowDict
    # first we save description
    rowDict[colist[0]] = row_tds[2].text # so the big assumption is that we always get description in 3rd column
    # then link to the ad from the image in the second column
    rowDict[colist[1]] = "https://ss.com" + row_tds[1].find('a').get('href')
    # then we take the rest of the table data elements and use them as values for our dictionary with keys being the column names
    for td,key in zip(row_tds[3:],colist[2:]): # we zip two lists together and iterate over them
        # when we zip two collections together we get pairs of elements until one of the collections run out of elements
        rowDict[key] = td.text
    return rowDict

# %%
apt_rows[0] # first row of ads
# Out:
# <tr id="tr_57271512"><td class="msga2 pp0"><input id="c57271512" name="mid[]" type="checkbox" value="57271512_1106_0"/></td><td class="msga2"><a href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="im57271512"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/8/1457/364075/72814873.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JUExJTlBdnQlQTclOEQlOTUlRUElQTElOUR1dyVBMiU4OSU5OCVBNCVBOSU5N3h2JUE3JTg1JTk4JTlFJUEwJTk2|pfBBrUdn" href="/msg/en/real-estate/flats/riga/centre/bdimo.html" id="dm_57271512">Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Avotu 23A</td><td c="1" class="msga2-o pp6" nowrap="">2</td><td c="1" class="msga2-o pp6" nowrap="">52</td><td c="1" class="msga2-o pp6" nowrap="">2/2</td><td c="1" class="msga2-o pp6" nowrap="">Pre-war house</td><td c="1" class="msga2-o pp6" nowrap="">10.58 €</td><td c="1" class="msga2-o pp6" nowrap="">550  €/mon.</td></tr>

# %%
# so getRow function needs a table row element
getRow(apt_rows[0])
# Out:
# {'description': 'Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo',
#  'url': 'https://ss.com/msg/en/real-estate/flats/riga/centre/bdimo.html',
#  'Street': 'Avotu 23A',
#  'R.': '2',
#  'm²': '52',
#  'Floor': '2/2',
#  'Series': 'Pre-war house',
#  'Price, m2': '10.58 €',
#  'Price': '550  €/mon.'}

# %% [markdown]
# ## Getting data for ALL rows
#
# If we have a function that can get needed data (and link) from a single row, we expect that all other rows with our apartments or other ads will be similar

# %%
# so if we can get a row we can get all rows
def getRows(rowlist,colist=column_names):
    """
    rowlist is a list of soup objects representing rows of the table
    colist is a list of column names
    """
    # return [getRow(row, colist=colist) for row in rowlist] # list comprehension
    # we could also do regular loop
    rowDicts = [] # we will store our data in a list of dictionaries
    # now we simply loop through our rowlist and call the getRow function on each then appending the resulting dictionary to our rowDicts list
    for row in rowlist:
        rowDicts.append(getRow(row, colist=colist))
    return rowDicts

# so we supply the row elements and out comes the list of dictionaries with the information about the ads

# %%
# let us call on all rows
row_ads = getRows(apt_rows)
row_ads[-3:] # check last three ads
# Out:
# [{'description': 'Īrei pieejams augstas klases, ekskluzīvs 4-istabu dzīvoklis Rīgā',
#   'url': 'https://ss.com/msg/en/real-estate/flats/riga/centre/bgfhx.html',
#   'Street': 'Rupniecibas 7',
#   'R.': '4',
#   'm²': '140',
#   'Floor': '2/5',
#   'Series': 'Recon.',
#   'Price, m2': '14.29 €',
#   'Price': '2,000  €/mon.'},
#  {'description': 'Ilgtermiņa īre, minimālais termiņš 1 gads, piedāvājam divistabu ',
#   'url': 'https://ss.com/msg/en/real-estate/flats/riga/centre/afojj.html',
#   'Street': 'Valdemara 77',
#   'R.': '2',
#   'm²': '52',
#   'Floor': '3/7',
#   'Series': 'Pre-war house',
#   'Price, m2': '11.92 €',
#   'Price': '620  €/mon.'},
#  {'description': 'Сдается уютная, солнечная квартира в новом проекте "Duntes Ozoli',
#   'url': 'https://ss.com/msg/en/real-estate/flats/riga/centre/bhdhp.html',
#   'Street': 'Duntes 28',
#   'R.': '2',
#   'm²': '65',
#   'Floor': '6/15',
#   'Series': 'New',
#   'Price, m2': '8.46 €',
#   'Price': '550  €/mon.'}]

# %%
type(row_ads) # so a list of dictionaries well suited for conversion to Pandas
# Out:
# list

# %%
row_ads[:2]  # first two ads
# Out:
# [{'description': 'Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo',
#   'url': 'https://ss.com/msg/en/real-estate/flats/riga/centre/bdimo.html',
#   'Street': 'Avotu 23A',
#   'R.': '2',
#   'm²': '52',
#   'Floor': '2/2',
#   'Series': 'Pre-war house',
#   'Price, m2': '10.58 €',
#   'Price': '550  €/mon.'},
#  {'description': 'Ilgtermiņa īrei pieejams pilnībā mēbelēts divu guļamistabu dzīvo',
#   'url': 'https://ss.com/msg/en/real-estate/flats/riga/centre/dgemg.html',
#   'Street': 'Avotu 23A',
#   'R.': '2',
#   'm²': '43',
#   'Floor': '2/2',
#   'Series': 'Pre-war house',
#   'Price, m2': '13.95 €',
#   'Price': '600  €/mon.'}]

# %%
# we can pass our list of dictionaries to pandas and create a dataframe
# dtemp = pd.DataFrame(row_ads, columns=column_names) # i do not need column names
# because column names are already encoded in invidual row dictionaries
dtemp = pd.DataFrame(row_ads)
dtemp.shape
# Out:
# (30, 9)

# %%
dtemp.head()
# Out:
#                                          description  \
# 0  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 1  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 2  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 3  Dzīvoklis pilsētas centrā ar stāvvietu mājas p...
# 4  Kompakts studio tipa 1 istabas dzīvoklis Rīgas...
#
#                                                  url        Street R.   m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2   52
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2   43
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2   49
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...  Brivibas 163  4  109
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...     Elijas 12  1   20
#
#   Floor         Series Price, m2          Price
# 0   2/2  Pre-war house   10.58 €    550  €/mon.
# 1   2/2  Pre-war house   13.95 €    600  €/mon.
# ...

# %%
# now you can save it to a file in a format you like, such as csv or excel
# dtemp.to_excel("centrs_30.xlsx")
# aganskalns_30.xlsx
# dtemp.to_excel("aganskalns_30.xlsx")
dtemp.to_excel("centers_27012026.xlsx")

# %%
# i could also download this file from Google Colab to my computer
from google.colab import files
files.download("centers_27012026.xlsx")

# %% [markdown]
# ## Getting ALL classified from ALL Urls
#
# If we can process one page, then we can process all pages and then glue them together!

# %%
# we have the list of urls already!
# let's call our function on all of them
# and combine the results into one dataframe
# let's make a function for this and also provid a small delay between requests
def get_dataframe_from_url(url, column_names):
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to get response from {url}")
        return None # so I return None if response was not 200 - not good
    print(f"Successfully got response from {url}")
    soup = BeautifulSoup(response.text, 'lxml') # parse HTML into soup
    rows = getRowList(soup) # call my row list function
    row_ads = getRows(rows, colist=column_names) # get rows using our column names
    return pd.DataFrame(row_ads) # so this gets us one dataframe (30x something)

# now for all
def get_big_dataframe(urls, delay=0.2):
    # we should get column names from first url
    response = requests.get(urls[0])
    if response.status_code != 200:
        print(f"Failed to get response from {urls[0]}")
        return None # so I return None if response was not 200 - not good
    soup = BeautifulSoup(response.text, 'lxml') # parse HTML into soup
    column_names = getColList(soup)
    print(f"Column names: {column_names}")
    url_list = []
    for url in urls:
        print(f"Getting data from {url}")
        df = get_dataframe_from_url(url, column_names = column_names)
        if df is not None:
            url_list.append(df)
        time.sleep(delay) # sleep for a second or less here 300 milliseconds
    # then we simply concatanate all the results together
    big_df = pd.concat(url_list, ignore_index=True) # so here we glue (concatenate ) multiple dataframes together, could be 2 could be 50
    return big_df

# %%
urls # we made this list earlier
# Out:
# ['https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page2.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page3.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page4.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page5.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page6.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page7.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page8.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page9.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page10.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page11.html',
#  'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page12.html',
# ...

# %%
big_df = get_big_dataframe(urls)
# Out:
# Column names: ['description', 'url', 'Street', 'R.', 'm²', 'Floor', 'Series', 'Price, m2', 'Price']
# Getting data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/
# Successfully got response from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/
# Getting data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page2.html
# Successfully got response from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page2.html
# Getting data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page3.html
# Successfully got response from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page3.html
# Getting data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page4.html
# Successfully got response from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page4.html
# Getting data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page5.html
# ...

# %%
# let's see shape and head
print(f"Shape: {big_df.shape}")
# head
big_df.head()
# Out:
# Shape: (710, 9)
#                                          description  \
# 0  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 1  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 2  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 3  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 4  Dzīvoklis pilsētas centrā ar stāvvietu mājas p...
#
#                                                  url        Street R.   m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2   42
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2   52
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2   43
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2   49
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...  Brivibas 163  4  109
#
#   Floor         Series Price, m2          Price
# 0   2/2  Pre-war house   13.10 €    550  €/mon.
# 1   2/2  Pre-war house   10.58 €    550  €/mon.
# ...

# %% [markdown]
# ## Saving Table with Custom datatime in file name

# %%
# now let's save to excel with datetime in the name
now = datetime.now()
dt_string = now.strftime("%Y%m%d_%H%M%S")# a little trick to add datetime to file name
# filename = f"aganskalns_{dt_string}.xlsx"
filename = f"centrs_{dt_string}.xlsx"
print(f"Filename: {filename}")
big_df.to_excel(filename)
# Out:
# Filename: centrs_20260127_180252.xlsx

# %%
# let's also save the csv
csv_filename = f"centrs_{dt_string}.csv"
print(f"CSV Filename: {csv_filename}")
big_df.to_csv(csv_filename, index=False)
# Out:
# CSV Filename: centrs_20260127_180252.csv

# %% [markdown]
# ## Cleaning up downladed table of data

# %%
# now the work would start on cleaning, transforming , analyzing the data, for one we could clean the prices from Euro signs etc.

# %%
# let us download the file
from google.colab import files
files.download(filename)

# %%
# I can save files in my Google Drive as well do not have to download
from google.colab import drive
drive.mount('/content/drive')

# %%
# so above approach works for static pages
# if we have dynamic pages we need to use selenium - which launches a browser controlled by python
# the methods are quite similar but we need to use selenium to get the response

# %% [markdown]
# ## Getting File Name automatically
#
# Idea we can use URL to obtain relevant file name
#
# Such as riga center hand_over for rentals

# %%
tokens = centrs.split("/")
tokens
# Out:
# ['https:',
#  '',
#  'www.ss.com',
#  'en',
#  'real-estate',
#  'flats',
#  'riga',
#  'centre',
#  'hand_over',
#  '']

# %%
prefix = tokens[-3]+"_"+tokens[-2]
prefix
# Out:
# 'centre_hand_over'

# %%
# little aside on how to create file name with date and time in it
from datetime import datetime

# %%
now = datetime.now()
now.year, now.month, now.day, now.hour, now.minute
# Out:
# (2026, 1, 27, 18, 5)

# %%
# example how we can automatically create a file name from URL and datetime
fname = f"{prefix}_{now.month}_{now.day}_{ now.hour}_{ now.minute}.xlsx"
fname
# Out:
# 'centre_hand_over_1_27_18_5.xlsx'

# %%
datetime.timestamp()
# Out:
# <method 'timestamp' of 'datetime.datetime' objects>

# %%
def getDFfromURL(url, save_to_excel=False):
    """
    url is a string representing a url of a page on ss.com
    save_to_excel is a boolean indicating if we want to save the data to excel file
    """
    # print("getting data from", url)
    req = requests.get(url)
    if req.status_code != 200: # check if we got a good response
        print("Request Fail with", req.status_code)
        return None # maybe return empty dataframe here
    soup = BeautifulSoup(req.text, 'lxml')
    column_names = getColList(soup) # so we utilize the functions we created earlier
    rowlist = getRowList(soup)
    rows = getRows(rowlist,colist=column_names)
    df = pd.DataFrame(rows, columns=column_names)
    if save_to_excel:
        tokens = url.split("/") # split url by / to get the prefix for the file name
        prefix = tokens[-3]+"_"+tokens[-2] # we get the prefix from the url
        now = datetime.now() # get current date and time
        fname = f"{prefix}_{now.month}_{now.day}_{now.hour}_{now.minute}.xlsx"
        df.to_excel(fname)
    return df

# %%
centrs
# Out:
# 'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/'

# %%
agens = "https://www.ss.com/lv/real-estate/flats/riga/agenskalns/hand_over/"
agens
# Out:
# 'https://www.ss.com/lv/real-estate/flats/riga/agenskalns/hand_over/'

# %%
agens_df = getDFfromURL(agens, save_to_excel=True)
agens_df.head(10)  # see first 10 ads
# Out:
#                                          description  \
# 0  Izīrē vienistabu dzīvokli 320, 00. Liela virtu...
# 1  Renovētā ēkā tiek izīrēts divistabu dzīvoklis ...
# 2  Izrīrē 2-istabu dzīvokli Āgenskalnā. Ļoti ērta...
# 3  Uz ilgu laiku, vismaz 1 gadu tiek izīrēts eksk...
# 4  Bez komisijas maksas, ilgtermiņā izīrējam 2 is...
# 5  4 istabu dzīvoklis. Bez komisijas maksas. \n\n...
# 6  Īpašnieks izīrē klusu dzīvokli blakus Radisson...
# 7  Tiek izīrēts labi uzturēts un kopts dzīvoklis ...
# 8  Meitenei/sievietei izīrē istabu (12, 5m2) ar j...
# 9  Piedāvā īpašnieks bez starpniekiem. Dzīvoklis ...
#
#                                                  url          Iela Ist.    m²  \
# 0  https://ss.com/msg/lv/real-estate/flats/riga/a...  M. Nometņu 9    1    38
# 1  https://ss.com/msg/lv/real-estate/flats/riga/a...     Alīses 2C    2    57
# 2  https://ss.com/msg/lv/real-estate/flats/riga/a...   Kristapa 24    2  4670
# ...

# %%
agens_sell = getDFfromURL("https://www.ss.com/lv/real-estate/flats/riga/agenskalns/sell/")
agens_sell.head(10)
# Out:
#                                          description  \
# 0  Viens no labākajiem augšējo stāvu penthousiem ...
# 1  Pārdošanā lieliski dzīvokļi ar pilnu apdari pi...
# 2  Pārdošanā lieliski dzīvokļi ar pilnu apdari pi...
# 3  Dzīvoklis ar privātuma sajūtu. Mājas otrajā st...
# 4  Tikai divi dzīvokļi mājas otrajā stāvā. \n\nDz...
# 5  Mājīgs un silts miniatūrais dzīvoklis blakus K...
# 6  Ekskluzīvs 3 istabu dzīvoklis Ķīpsalā – tikai ...
# 7  Attīstītājs un īpašnieks – kompāniju grupa R. ...
# 8  Pasteidzies iegādāties pēdējos divus 3 istabas...
# 9  Tiek pārdots mūsdienīgs divīstabu dzīvoklis re...
#
#                                                  url          Iela Ist.   m²  \
# 0  https://ss.com/msg/lv/real-estate/flats/riga/a...       Kuģu 28    5  219
# 1  https://ss.com/msg/lv/real-estate/flats/riga/a...  Lielirbes 9a    2   45
# 2  https://ss.com/msg/lv/real-estate/flats/riga/a...  Lielirbes 9a    3   47
# ...

# %%
df = getDFfromURL(centrs, save_to_excel=True)

# %%
df.shape
# Out:
# (30, 9)

# %%
df.head()
# Out:
#                                          description  \
# 0  Divistabu dzīvoklis ar bezmaksas stāvvietu pie...
# 1  Izīrē pilnībā mēbelētu dzīvokli jaunāja projek...
# 2  Izīrē pilnībā mēbelētu dzīvokli pilsētas centr...
# 3  Izīrē 2-istabu dzīvokli pēc kapitālā remonta a...
# 4  Īpašniece piedāvā īrei ērtu, studijas tipa dzī...
#
#                                                  url          Street R.  m2  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...        Miera 97  2  39
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...    Terbatas 26a  2  31
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...    Terbatas 26a  2  43
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...       Chaka 148  2  60
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...  Artilerijas 19  1  35
#
#   Floor    Series Price, m2        Price
# 0   4/5  Chrusch.    8.46 €  330  €/mon.
# 1   2/5       New   14.52 €  450  €/mon.
# 2   1/6       New   10.47 €  450  €/mon.
# ...

# %% [markdown]
# ## Now we want to find all pages with the same ads from the area
# ### some urls might have many ads some might have a single page

# %%
# https://developer.mozilla.org/en-US/docs/Web/HTML/Element/a
anchors = soup.find_all("a")
len(anchors)
# anchors are the basic building blocks of the web, so we have a lot of them
# Out:
# 99

# %%
anchors[:5]
# Out:
# [<a href="/en/" title="Advertisements"><img alt="Advertisements" border="0" class="page_header_logo" src="https://i.ss.com/img/p.gif"/></a>,
#  <a class="a_menu" href="/en/real-estate/flats/new/" title="Post Advertisement">Post Advertisement</a>,
#  <a class="a_menu" href="/en/login/" title="My Adverts">My Adverts</a>,
#  <a class="a_menu" href="/en/real-estate/flats/riga/centre/search/" title="Search advertisement">Search</a>,
#  <a class="a_menu" href="/en/favorites/" title="Favorites">Favorites</a>]

# %%
# we want the previous anchor it has a couple of attributes that we can use to find it
# one way is to use name attribute and check if it is equal to nav_id
navs = [anchor for anchor in anchors if anchor.get("name") == "nav_id"] # get will get us None if no "name" exists
len(navs)
# Out:
# 10

# %%
navs[0] # so the first one is the one we want
# Out:
# <a class="navi" href="/en/real-estate/flats/riga/centre/sell/page26.html" name="nav_id" rel="prev"><img border="0" height="5" src="https://i.ss.com/img/s_left.png" style="padding-bottom:2px;" width="9"/> Previous</a>

# %%
navs[0].attrs
# Out:
# {'name': 'nav_id',
#  'rel': ['prev'],
#  'class': ['navi'],
#  'href': '/en/real-estate/flats/riga/centre/sell/page26.html'}

# %%
navs[0]['href'] # we can extract the link from the anchor
# Out:
# '/en/real-estate/flats/riga/centre/sell/page26.html'

# %%
# could use regular expression here but we can use split
afterpage = navs[0]['href'].split("/page")[-1] # -1 might be safer than 1 in case there is region with name page
afterpage
# Out:
# '26.html'

# %%
beforedot = afterpage.split(".html")[0] # first part of the split
beforedot
# Out:
# '26'

# %%
# we have extracted the number of the page finally we need to convert it to integer
lastpage = int(beforedot)  # need to cast this to integer
lastpage
# Out:
# 26

# %%
# now we can use that number to create a list of urls for all pages

# %%
def getAllLocalUrls(url):
    """Get a list of all urls including paginated pages
    url is a string representing a url of a page on ss.com where we start
    """
    results = [url] # default is just the url if no extra pages found like Boldaraja :)
    req = requests.get(url)
    if req.status_code != 200:
        print(f"Bad response! {req.status_code}")
        return []
    soup = BeautifulSoup(req.text, 'lxml')
    # we just need a one element
    # instead of name attribute we use rel attribute
    prevanchor = soup.find('a', {"rel":"prev"}) # this is specific to previous page anchor on ss.com
    # you would need to adjust this to your needs
    if prevanchor == None: # means there is only one page of ads
        return results
    # now we extact the number of the last page
    href = prevanchor.attrs.get('href')
    lastPageNum = int(href.split('/page')[-1].split('.html')[0])
    print("Last page is",lastPageNum)
    # finally we use list comprehension to create a list of urls
    # also note the use of f-string to create the url
    nurls = [f"{url}page{n}.html" for n in range(2,lastPageNum+1)]
    results += nurls
    return results

# %%
centrs
# Out:
# 'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/'

# %%
local_urls = getAllLocalUrls(centrs)
len(local_urls),local_urls[:3],local_urls[-3:]
# Out:
# Last page is 24
# (24,
#  ['https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/',
#   'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page2.html',
#   'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page3.html'],
#  ['https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page22.html',
#   'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page23.html',
#   'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page24.html'])

# %%
dlast = getDFfromURL(local_urls[-1])
dlast.shape
# Out:
# (21, 9)

# %%
dlast
# Out:
#                                           description  \
# 0   Цена проживания 50 евро за одну ночь с воскрес...
# 1   Find Your Perfect Student Home for the Upcomin...
# 2   Available from 5th of September. 600 euro per ...
# 3   Komunālie maksājumi iekļauti īres maksā. Drošī...
# 4   No 02.02. ilgtermiņā izīrē dzīvokli lieliskā v...
# 5   Moderns dzīvoklis starp lidostu un Rīgas centr...
# 6   Mājīgs 3 guļamistabu dzīvoklis klusajā centrā ...
# 7   Izīrē gaišu, saulainu un plašu, pilnībā mēbelē...
# 8   Izīrē tikko izremontētu mājīgu un gaišu 4 ista...
# 9   Izīrē studiju jaunbūves projektā – ideāla izvē...
# 10  Jauns remonts. Izīrēju 1-istabas studio tipa d...
# 11  Gaišs, silts un mājīgs studijas dzīvoklis cent...
# 12  Tiek izīrēts jauks un saulains 2 istabu dzīvok...
# 13  Living space as art: every day in harmony and ...
# 14  Tiek izīrēts ilgtermiņa īrei 4 istabu dzīvokli...
# 15  Ja sapņo par mājām mierīgā, zaļā un sakoptā vi...
# ...

# %%
def get_all_ads_df(start_url, save_excel_path=None, delay=0.2):
    """Get a dataframe of all ads from a given url
    start_url is a string representing a url of a page on ss.com where we start
    save_excel_path is a string representing a path to save the excel file
    """
    df_list=[] # so we will save our dataframes in a list
    local_urls = getAllLocalUrls(start_url)
    for url in local_urls:
        print(f"Gathering data from {url}")
        df_list.append(getDFfromURL(url))
        time.sleep(delay) # we need this to play nice! we want a little bit of delay (300ms here) to not overload the server
    # https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html
    big_df = pd.concat(df_list) # then make a big dataframe from all the small dataframes - tables
    if save_excel_path:
        big_df.to_excel(save_excel_path)
    return big_df

# %%
kenga_url = "https://www.ss.com/en/real-estate/flats/riga/kengarags/hand_over/"
kenga_df = get_all_ads_df(kenga_url, "kenga_27_01_2026.xlsx")
kenga_df.head()
# Out:
# Last page is 3
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/kengarags/hand_over/
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/kengarags/hand_over/page2.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/kengarags/hand_over/page3.html
#                                          description  \
# 0  Сдаю 1-комнатную Малогабаритную квартиру 12 кв...
# 1  Īpašnieks izīrē labiekārtotu, mēbelētu 1 - ist...
# 2  Izīrē vienu istabu privātas divstāvu ēkas pirm...
# 3  Tiek piedāvāts mājīgs divistabu dzīvokļis jaun...
# 4  Izremontēts, gaišs dzīvoklis Ķengaragā. \n\nAt...
#
#                                                  url          Street R.  m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/k...  Krustpils 75/5  1  12
# 1  https://ss.com/msg/en/real-estate/flats/riga/k...       Vishku 23  1  30
# 2  https://ss.com/msg/en/real-estate/flats/riga/k...       Prushu 69  1  15
# ...

# %%
range_rover_url = "https://www.ss.com/en/transport/cars/land-rover/sell/"
range_rover_df = get_all_ads_df(range_rover_url, "range_rover_27_01_2026.xlsx")
range_rover_df.head()
# Out:
# Last page is 9
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/page2.html
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/page3.html
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/page4.html
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/page5.html
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/page6.html
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/page7.html
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/page8.html
# Gathering data from https://www.ss.com/en/transport/cars/land-rover/sell/page9.html
#                                          description  \
# 0  Range Rover Evoque 2013.gads 4x4 2.2d automāts...
# 1  Land Rover Discovery Sport 2.0D\n\nViens īpašn...
# ...

# %% [markdown]
# ## Practical Exercise in Class
#
# 1. Find two urls that you are interesed in ss.com (or ss.lv)
# 2. Create and save two xlsx files with ALL the ads for those urls
#
# Hint: call the get_all_ads_df function with correct url and file name to save
#
# 3. Then try using Generate Code or Transform Code to clean Euro signs from Price column - We will do this in class after 21:05
#
# Troubleshooting tip: Use Explain Error for Gemini to help if any errors appear
#
# ### BONUS tasks which we will look at after 21:00
#
# Cleaning data, for example getting prices as floating points
# Creating new columns such as Floor and MaxFloor for apartments

# %% [markdown]
# ## Cleaning Results

# %%
centrs
# Out:
# 'https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/'

# %%
# let's get the freshest data
df = get_all_ads_df(centrs, "centrs_for_rent_27_01_2026.xlsx")
df.head()
# Out:
# Last page is 24
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page2.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page3.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page4.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page5.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page6.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page7.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page8.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page9.html
# Gathering data from https://www.ss.com/en/real-estate/flats/riga/centre/hand_over/page10.html
# ...

# %%
# what is overall shape?
df.shape
# Out:
# (710, 9)

# %%
df.head()
# Out:
#                                          description  \
# 0  Tiek izīrēts plašs trīsistabu dzīvoklis. Bez k...
# 1  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 2  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 3  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 4  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
#
#                                                  url        Street R.  m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...  Gertrudes 69  3  80
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  42
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  52
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  43
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  49
#
#   Floor         Series Price, m2        Price
# 0   2/6         Recon.    8.75 €  700  €/mon.
# 1   2/2  Pre-war house   13.10 €  550  €/mon.
# 2   2/2  Pre-war house   10.58 €  550  €/mon.
# ...

# %%
# so the steps of the process are:
# 1. get the list of urls for all pages
# 2. get the data from each page
# 3. combine the data into one dataframe
# 4. save the dataframe to excel for further analysis

# %%
# what is the limitation of BeautifulSoup?
# it is not a browser, it does not execute javascript!
# modern web pages are not just html, they are html + css + javascript quite often
# often the page is not fully loaded until javascript is executed
# that is where Selenium comes in
# Selenium is a browser automation tool
# this means you can use it to automate the browser
# that is more powerful than BeautifulSoup but slower

# %%
df.tail()
# Out:
#                                           description  \
# 15  Ja sapņo par mājām mierīgā, zaļā un sakoptā vi...
# 16  Dizainera veidots dzīvoklis pašā Rīgas sirdī v...
# 17  A room with shared kitchen and bathroom, Cente...
# 18  Apartment for Rent in the Center of Riga / Ква...
# 19  4 взрослых. Цена проживания 60 евро за одну но...
#
#                                                   url          Street R.  m²  \
# 15  https://ss.com/msg/en/real-estate/flats/riga/c...        Stabu 95  3  66
# 16  https://ss.com/msg/en/real-estate/flats/riga/c...  Raina boul. 27  2  45
# 17  https://ss.com/msg/en/real-estate/flats/riga/c...   Benjamiņas 12  1  20
# 18  https://ss.com/msg/en/real-estate/flats/riga/c...   Benjamiņas 12  3  50
# 19  https://ss.com/msg/en/real-estate/flats/riga/c...   Elizabetes 22  2  47
#
#    Floor   Series Price, m2        Price
# 15   4/5   Recon.    9.85 €  650  €/mon.
# 16   4/5   Recon.    1.44 €    65  €/day
# 17   2/3  Lit pr.      14 €  280  €/mon.
# ...

# %% [markdown]
# ## Feature Engineering - New Columns from old

# %%
#we can do more post processing - feature engineering using existing columns
# we use split this time applied to a column values
# we create two new columns for storing values of the split
df[['CurFloor','MaxFloor']] = df.Floor.str.split("/",expand=True)
df.head()
# Out:
#                                          description  \
# 0  Tiek izīrēts plašs trīsistabu dzīvoklis. Bez k...
# 1  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 2  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 3  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 4  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
#
#                                                  url        Street R.  m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...  Gertrudes 69  3  80
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  42
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  52
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  43
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  49
#
#   Floor         Series Price, m2        Price CurFloor MaxFloor
# 0   2/6         Recon.    8.75 €  700  €/mon.        2        6
# 1   2/2  Pre-war house   13.10 €  550  €/mon.        2        2
# ...

# %%
# we attempt to sort by MaxFloor in descending order
df.sort_values(by="MaxFloor",ascending=False).head() # Why is 9 at the top? for MaxFloor, don't we have floor 12 or 24?
# Out:
#                                           description  \
# 5   Jaunajā projektā ar tikko pabeigtu apdari un j...
# 12  Gaiši, mājīgi 3-istabu apartamenti bez starpni...
# 1   Moderns, daļēji mēbelēts A+ energoefektivitāte...
# 25  For rent a spacious and cozy 2-bedroom apartme...
# 25  Izīrēju modernu dzīvokli jaunā projekta ēkā. S...
#
#                                                   url        Street R.  m²  \
# 5   https://ss.com/msg/en/real-estate/flats/riga/c...      Klusa 20  1  30
# 12  https://ss.com/msg/en/real-estate/flats/riga/c...     Klijanu 6  3  68
# 1   https://ss.com/msg/en/real-estate/flats/riga/c...  Latgales 192  2  38
# 25  https://ss.com/msg/en/real-estate/flats/riga/c...  Grostonas 21  3  98
# 25  https://ss.com/msg/en/real-estate/flats/riga/c...      Klusa 18  1  30
#
#    Floor  Series Price, m2          Price CurFloor MaxFloor
# 5    3/9     New       1 €      30  €/day        3        9
# 12   6/9     New   13.24 €    900  €/mon.        6        9
# ...

# %%
# let's do value counts for MaxFloor
df.MaxFloor.value_counts() # shows most popular maxfloor for the buildings
# Out:
# MaxFloor
# 5     286
# 6     187
# 4      58
# 7      55
# 3      46
# 9      26
# 2      20
# 10      6
# 1       5
# 8       5
# 12      5
# 15      3
# 16      3
# 23      2
# 11      1
# 24      1
# 14      1
# Name: count, dtype: int64

# %%
# our data types have not been converted yet!
# object is basically a string that can hold anything
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 710 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  710 non-null    object
#  1   url          710 non-null    object
#  2   Street       710 non-null    object
#  3   R.           710 non-null    object
#  4   m²           710 non-null    object
#  5   Floor        710 non-null    object
#  6   Series       710 non-null    object
#  7   Price, m2    710 non-null    object
#  8   Price        710 non-null    object
#  9   CurFloor     710 non-null    object
#  10  MaxFloor     710 non-null    object
# dtypes: object(11)
# memory usage: 66.6+ KB

# %%
# let's split Price column by "€/"
# we will create two new columns PurePrice and Duration
df[['PurePrice','Duration']] = df.Price.str.split("€/",expand=True)
df.head()
# Out:
#                                          description  \
# 0  Tiek izīrēts plašs trīsistabu dzīvoklis. Bez k...
# 1  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 2  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 3  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 4  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
#
#                                                  url        Street R.  m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...  Gertrudes 69  3  80
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  42
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  52
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  43
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  49
#
#   Floor         Series Price, m2        Price CurFloor MaxFloor PurePrice  \
# 0   2/6         Recon.    8.75 €  700  €/mon.        2        6     700
# ...

# %%
# next remove any punctuation from PurePrice column
df.PurePrice = df.PurePrice.str.replace(",","") # so replace , with whatever you want removed
df.head()
# Out:
#                                          description  \
# 0  Tiek izīrēts plašs trīsistabu dzīvoklis. Bez k...
# 1  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 2  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 3  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 4  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
#
#                                                  url        Street R.  m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...  Gertrudes 69  3  80
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  42
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  52
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  43
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  49
#
#   Floor         Series Price, m2        Price CurFloor MaxFloor PurePrice  \
# 0   2/6         Recon.    8.75 €  700  €/mon.        2        6     700
# ...

# %%
# let's create a new cena column from PurePrice by attempting numeric conversion
df["Cena"] = pd.to_numeric(df.PurePrice) #if I do not add any extra paramters this can fail
df.head()
# Out:
#                                          description  \
# 0  Tiek izīrēts plašs trīsistabu dzīvoklis. Bez k...
# 1  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 2  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 3  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 4  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
#
#                                                  url        Street R.  m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...  Gertrudes 69  3  80
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  42
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  52
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  43
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2  49
#
#   Floor         Series Price, m2        Price CurFloor MaxFloor PurePrice  \
# 0   2/6         Recon.    8.75 €  700  €/mon.        2        6     700
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 710 entries, 0 to 19
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  710 non-null    object
#  1   url          710 non-null    object
#  2   Street       710 non-null    object
#  3   R.           710 non-null    object
#  4   m²           710 non-null    object
#  5   Floor        710 non-null    object
#  6   Series       710 non-null    object
#  7   Price, m2    710 non-null    object
#  8   Price        710 non-null    object
#  9   CurFloor     710 non-null    object
#  10  MaxFloor     710 non-null    object
#  11  PurePrice    710 non-null    object
#  12  Duration     710 non-null    object
#  13  Cena         710 non-null    int64
# dtypes: int64(1), object(13)
# memory usage: 83.2+ KB

# %%
# Let's see what type of Duration we have and value counts
df.Duration.value_counts()
# Out:
# Duration
# mon.    624
# day      82
# week      4
# Name: count, dtype: int64

# %%
# let's create a new MontlyPrice column
# it will be determined as follows
# if Duration is "mon." then we use Cena as is
# if Duration is "day" then MonthlyPrice value is Cena * 365 / 12
# if Duration is "week" then MonthlyPrice value is Cena * 52 / 12 # not perfect but close
# so we could just start by copying Cena as is
df["MonthlyPrice"] = df.Cena
# then only apply the logic when Duration is "week" and "day"
# we will use .loc indexer
df.loc[df["Duration"]=="day","MonthlyPrice"] = df.loc[df["Duration"]=="day","Cena"] * 365 / 12
df.loc[df["Duration"]=="week","MonthlyPrice"] = df.loc[df["Duration"]=="week","Cena"] * 52 / 12
df.head()
# Out:
# /tmp/ipython-input-1461356767.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[ 760.41666667 1064.58333333  608.33333333  882.08333333 1216.66666667
#   912.5        1216.66666667 1064.58333333 1064.58333333 1825.
#   882.08333333 1064.58333333 1216.66666667 1520.83333333 1095.
#  1216.66666667 1977.08333333  760.41666667 1216.66666667 1216.66666667
#   912.5        1216.66666667 1216.66666667  912.5         760.41666667
#  1825.          882.08333333 1095.         1216.66666667 1216.66666667
#  1064.58333333 1216.66666667  851.66666667 1216.66666667  912.5
#   912.5        1216.66666667 1520.83333333 1672.91666667 2433.33333333
#  1825.         1216.66666667  912.5        1064.58333333 1520.83333333
#  1825.          760.41666667 1064.58333333 1520.83333333  912.5
#   912.5        1064.58333333  912.5         821.25       1825.
#  1216.66666667 1216.66666667 1520.83333333 1977.08333333 2737.5
# ...

# %%
# let's try converting CurFloor and MaxFloor as well to numeric
df.CurFloor = pd.to_numeric(df.CurFloor)
df.MaxFloor = pd.to_numeric(df.MaxFloor)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 710 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   description   710 non-null    object
#  1   url           710 non-null    object
#  2   Street        710 non-null    object
#  3   R.            710 non-null    object
#  4   m²            710 non-null    object
#  5   Floor         710 non-null    object
#  6   Series        710 non-null    object
#  7   Price, m2     710 non-null    object
#  8   Price         710 non-null    object
#  9   CurFloor      710 non-null    int64
#  10  MaxFloor      710 non-null    int64
#  11  PurePrice     710 non-null    object
#  12  Duration      710 non-null    object
#  13  Cena          710 non-null    int64
#  14  MonthlyPrice  710 non-null    float64
# dtypes: float64(1), int64(3), object(11)
# memory usage: 88.8+ KB

# %%
# let's try converting "R." column to numeric
# we want NaN if conversion is not possible
df["R."] = pd.to_numeric(df["R."], errors="coerce")
# so coerce guarantees conversion
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 710 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   description   710 non-null    object
#  1   url           710 non-null    object
#  2   Street        710 non-null    object
#  3   R.            709 non-null    float64
#  4   m²            710 non-null    object
#  5   Floor         710 non-null    object
#  6   Series        710 non-null    object
#  7   Price, m2     710 non-null    object
#  8   Price         710 non-null    object
#  9   CurFloor      710 non-null    int64
#  10  MaxFloor      710 non-null    int64
#  11  PurePrice     710 non-null    object
#  12  Duration      710 non-null    object
#  13  Cena          710 non-null    int64
#  14  MonthlyPrice  710 non-null    float64
# dtypes: float64(2), int64(3), object(10)
# memory usage: 88.8+ KB

# %%
# let's convert m² column as well
df["m²"] = pd.to_numeric(df["m²"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 710 entries, 0 to 19
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   description   710 non-null    object
#  1   url           710 non-null    object
#  2   Street        710 non-null    object
#  3   R.            709 non-null    float64
#  4   m²            710 non-null    int64
#  5   Floor         710 non-null    object
#  6   Series        710 non-null    object
#  7   Price, m2     710 non-null    object
#  8   Price         710 non-null    object
#  9   CurFloor      710 non-null    int64
#  10  MaxFloor      710 non-null    int64
#  11  PurePrice     710 non-null    object
#  12  Duration      710 non-null    object
#  13  Cena          710 non-null    int64
#  14  MonthlyPrice  710 non-null    float64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 88.8+ KB

# %%
# let's sort by MaxFloor now in descending
df.sort_values(by="MaxFloor",ascending=False).head()
# Out:
#                                           description  \
# 13  Сдаётся просторная однокомнатная квартира в пр...
# 2   Сдается просторная, светлая 2х комнатная кварт...
# 7   Сдаётся просторная и светлая двухкомнатная ква...
# 16  Burvīgais 3 istabu studio tipa dzīvoklis jauna...
# 4   Burvīgais 2 istabu studio tipa dzīvoklis jauna...
#
#                                                   url        Street   R.   m²  \
# 13  https://ss.com/msg/en/real-estate/flats/riga/c...   Skanstes 29  1.0   44
# 2   https://ss.com/msg/en/real-estate/flats/riga/c...  Skanstes 29a  2.0   65
# 7   https://ss.com/msg/en/real-estate/flats/riga/c...   J. Dalina 8  2.0   66
# 16  https://ss.com/msg/en/real-estate/flats/riga/c...     Duntes 28  3.0  106
# 4   https://ss.com/msg/en/real-estate/flats/riga/c...     Duntes 28  2.0   40
#
#     Floor     Series Price, m2          Price  CurFloor  MaxFloor PurePrice  \
# 13   3/24        New   15.91 €    700  €/mon.         3        24     700
# ...

# %%
# let's see Series Value Counts for building types
df.Series.value_counts()
# Out:
# Series
# Pre-war house     289
# Recon.            220
# New               118
# Spec. pr.          40
# Stalin project     17
# Chrusch.           16
# Lit pr.             3
# 103-th              2
# 467-th              2
# 104-th              1
# Czech pr.           1
# Priv.house          1
# Name: count, dtype: int64

# %%
# let's group by Series column and provide descriptive statistics
df.groupby("Series").MonthlyPrice.describe()
# Out:
#                 count        mean         std    min     25%    50%  \
# Series
# 103-th            2.0  580.000000  381.837662  310.0  445.00  580.0
# 104-th            1.0  350.000000         NaN  350.0  350.00  350.0
# 467-th            2.0  550.000000  141.421356  450.0  500.00  550.0
# Chrusch.         16.0  463.880208  162.421685  280.0  352.50  425.0
# Czech pr.         1.0  500.000000         NaN  500.0  500.00  500.0
# Lit pr.           3.0  985.694444  883.877224  280.0  490.00  700.0
# New             118.0  972.483051  558.548649  260.0  600.00  850.0
# Pre-war house   289.0  716.714533  420.530492  140.0  440.00  600.0
# Priv.house        1.0  460.000000         NaN  460.0  460.00  460.0
# Recon.          220.0  981.060606  659.299397  225.0  500.00  750.0
# Spec. pr.        40.0  788.447917  749.187172  150.0  348.75  525.0
# Stalin project   17.0  575.269608  244.267477  250.0  400.00  550.0
#
#                         75%          max
# Series
# ...

# %%
# let's plot area the m2 column versus price
df.plot.scatter(x="m²", y="Cena")
# Out:
# <Axes: xlabel='m²', ylabel='Cena'>

# %%
# let's plot m2 versus MonthlyPrice which should give better picture of relationshop between square meters and rental price
df.plot.scatter(x="m²", y="MonthlyPrice")
# Out:
# <Axes: xlabel='m²', ylabel='MonthlyPrice'>

# %%
# let's again plot m2 versus cena columns
# let's color by Series column # so we shoe 3rd dimension - here this building type (Series)
# let's use Seaborn
import seaborn as sns
# let's use different color palette
sns.set_palette("colorblind")
# move legend to the right of plot
# sns.set_style() # TODO ask Gemini or Claude of ChatGPT for help but it should be easy
sns.scatterplot(data=df, x="m²", y="Cena", hue="Series")
# Out:
# <Axes: xlabel='m²', ylabel='Cena'>

# %%
# let's cut Monthly price into bins in 100 euro intervals and assign it to PriceCat column
# so let's have bins 0,200,300,400,500,600,700,800,900,1000 and up
bins = [0,200,300,400,500,600,700,800,900,1000,4000] # instead of 4000 we need np.infinity for completely correct
# labels = ["0_to_200", "200_300", ] # we could assign lables by hand but for now let's use auto labels
df["PriceCat"] = pd.cut(df.MonthlyPrice, bins=bins, labels=False)
df.head()
# Out:
#                                          description  \
# 0  Tiek izīrēts plašs trīsistabu dzīvoklis. Bez k...
# 1  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 2  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 3  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
# 4  Ilgtermiņa īrei pieejams pilnībā mēbelēts divu...
#
#                                                  url        Street   R.  m²  \
# 0  https://ss.com/msg/en/real-estate/flats/riga/c...  Gertrudes 69  3.0  80
# 1  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2.0  42
# 2  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2.0  52
# 3  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2.0  43
# 4  https://ss.com/msg/en/real-estate/flats/riga/c...     Avotu 23A  2.0  49
#
#   Floor         Series Price, m2        Price  CurFloor  MaxFloor PurePrice  \
# 0   2/6         Recon.    8.75 €  700  €/mon.         2         6     700
# ...

# %%
# let's plot our price categories column as histogram
df.PriceCat.hist()
# Out:
# <Axes: >

# %%
# let's see MonthlyPrice histogram
df.MonthlyPrice.hist(bins=20) #histograms have a downside as number of bins affect visual of the histogram
# Out:
# <Axes: >

# %%
# so we could do more cleanup
# we would need to convert weekly and daily prices to monthly
# perhaps partition square footage into bins/boxes say every 10 square meters
# we could also analyze streets etc etc - to place rent prices on map
# also we could get more data from whole of Riga or whole Latvia

# %%
# ok let's order our df by square meters m2
df.sort_values(by="m²",ascending=True, inplace=True)
df.head()
# Out:
#                                           description  \
# 25  Сдаю 1-комнату в 4-комнатной квартире. Комната...
# 8   Izīrē vienu mēbeletu un izolētu istabu trīs is...
# 19  Ilgtermiņa īrei piedāvājam mēbelētu istabu, pa...
# 14  Izīrējam mēbelētu istabu 13 m2 vienai personai...
# 29  Страховой депозит 100 евро. Cleaning fee (убор...
#
#                                                   url         Street   R.  m²  \
# 25  https://ss.com/msg/en/real-estate/flats/riga/c...  Lachplesha 62  1.0  10
# 8   https://ss.com/msg/en/real-estate/flats/riga/c...  Valdemara 123  1.0  10
# 19  https://ss.com/msg/en/real-estate/flats/riga/c...   Gertrudes 34  1.0  12
# 14  https://ss.com/msg/en/real-estate/flats/riga/c...         Upes 2  1.0  13
# 29  https://ss.com/msg/en/real-estate/flats/riga/c...  Gertrudes 129  1.0  14
#
#    Floor          Series Price, m2        Price  CurFloor  MaxFloor PurePrice  \
# 25   6/6   Pre-war house      20 €  200  €/mon.         6         6     200
# ...

# %%
# we could sort by Price, m2 column in ascending order to see best "deals"
# if there is equal deal then we sort by second column m² in this case
df.sort_values(by=["Price, m2","m²"],ascending=[True,True], inplace=True)
df.head(20)
# Out:
#                                           description  \
# 15  25-29 евро в сутки. Более 20 дней -27 евро в с...
# 4   Сдаётся 3-комнатная квартира, 78 М² (2 спальни...
# 11  Rīgas centrā, bet patīkami klusā un mierīgā vi...
# 28  Moderns dzīvoklis starp lidostu un Rīgas centr...
# 28  Студия в новом доме в центре. Свежий ремонт. П...
# 15  Elegants dzīvoklis ar privātu Spa kompleksu Rī...
# 0   Izīrēju gaišu un mājīgu 2 istabu dzīvokli proj...
# 18  Par dzīvokli:\nTikko renovēts, gaumīgi iekārto...
# 1   Bezmaksas autosstāvvieta. Izīrēju lieisku 2-is...
# 3   Dzīvoklis ar privātu Spa kompleksu pilsētas ce...
# 12  Elegants dzīvoklis ar privātu Spa kompleksu Rī...
# 15  Новый лофт (мансарда) в центре рядом с церковь...
# 19  Uz dažām stundām-lētāk. Brīvdienās, svētkos ce...
# 25  Izīrēju modernu dzīvokli jaunā projekta ēkā. S...
# 1   A great opportunity to rent cozy apartment for...
# 27  Bezmaksas autostāvvieta slēgtā teritorijā. Ieb...
# ...

# %%
## so we see our best deals are actually quite bad
# why?
# because we are using price per m2 supplied by ss.com
# and it is distorted by daily renters
# to fix it we need to calculate price per m2 from MonthlyPrice column
# let's create MonthlyPricePerM2 column
df["MonthlyPricePerM2"] = df.MonthlyPrice / df["m²"]
df.head()
# Out:
#                                           description  \
# 15  25-29 евро в сутки. Более 20 дней -27 евро в с...
# 4   Сдаётся 3-комнатная квартира, 78 М² (2 спальни...
# 11  Rīgas centrā, bet patīkami klusā un mierīgā vi...
# 28  Moderns dzīvoklis starp lidostu un Rīgas centr...
# 28  Студия в новом доме в центре. Свежий ремонт. П...
#
#                                                   url        Street   R.  m²  \
# 15  https://ss.com/msg/en/real-estate/flats/riga/c...      Stabu 17  2.0  57
# 4   https://ss.com/msg/en/real-estate/flats/riga/c...  Brivibas 313  3.0  78
# 11  https://ss.com/msg/en/real-estate/flats/riga/c...      Stabu 96  2.0  53
# 28  https://ss.com/msg/en/real-estate/flats/riga/c...   Valdemara 1  1.0  52
# 28  https://ss.com/msg/en/real-estate/flats/riga/c...      Klusa 20  1.0  35
#
#    Floor          Series Price, m2      Price  CurFloor  MaxFloor PurePrice  \
# 15   5/6          Recon.   0.509 €  29  €/day         5         6      29
# ...

# %%
# let's sort by MonthlyPricePerM2 in Ascending Order
df.sort_values(by="MonthlyPricePerM2",ascending=True, inplace=True)
df.head(20)
# Out:
#                                           description  \
# 5   Flexible Tenancy \nPerfect for Young Professio...
# 9   Ideal for Students, 5-bedroom apartment\nPrice...
# 20  Students and Young Professionals Welcome. \nFl...
# 0   На срок по договоренности сдаем прекрасное бла...
# 10  Ideal for Students, 4-bedroom apartment\nPrice...
# 3   Saulains divistabu dzīvoklis. \nGāze nav. \nĒk...
# 2   Mājas saimnieks, bez starpniekiem, izīrē 28 m2...
# 29      Malkas apkue. Gāzes plīts. Gatavs dzīvošanai.
# 18  Kamēr sludinājums ir redzams, piedāvājums ir p...
# 1   Сдаётся 3-комнатная квартира. Гостиная соедине...
# 8   Saimnieks Izīrē dzīvokli. Silts 3istabu dzīvok...
# 5   Сдаётся 3 комнатная квартира, 2 изолированные ...
# 3   Namīpašnieks bez starpniekiem izīre 4 ist dzīv...
# 26  Izīrē gaišu un mājīgu 3-istabu dzīvokli fasāde...
# 20  3 istabu dzīvoklis, 82 kv. m, 5/6 st. , pirmsk...
# 23  Īres maksā ir iekļauti komunālie maksājumi un ...
# ...

# %%
# let's create timestamp and save as xlsx
from datetime import datetime as dt
now = dt.now()
# create YYYY_MM_DD stamp
stamp = f"{now.year}_{now.month}_{now.day}"
stamp
# Out:
# '2026_1_27'

# %%
# let's save into xlsx file with stamp
filename = f"centrs_for_rent_{stamp}.xlsx"
filename
# Out:
# 'centrs_for_rent_2026_1_27.xlsx'

# %%
# let's save
df.to_excel(filename)

# %%
# let's download to local computer
from google.colab import files
files.download(filename)

# %%
url = "https://www.ss.com/lv/real-estate/flats/riga/sarkandaugava/hand_over/"
region = url.split("riga/")[-1].split("/")[0]
now = dt.now()
save_path = f"../data/{region}_{now.day}_{now.month}__{now.hour}_{now.second}.xlsx"
save_path

# %%
url = "https://www.ss.com/lv/real-estate/flats/riga/sarkandaugava/hand_over/"
region = url.split("riga/")[-1].split("/")[0]
now = dt.now()
save_path = f"../data/{region}_{now.day}_{now.month}__{now.hour}_{now.second}.xlsx"

df = get_all_ads_df(url, save_path)

# %%
url = "https://www.ss.com/lv/transport/cars/vaz/riga_f/"
df = get_all_ads_df(url, "../data/vaz_25_11.xlsx")

# %%
sarkandaugava_url = "https://www.ss.com/lv/real-estate/flats/riga/sarkandaugava/hand_over/"
sarkandaugava_url
# Out:
# 'https://www.ss.com/lv/real-estate/flats/riga/sarkandaugava/hand_over/'

# %%
sarkan_df = get_all_ads_df(sarkandaugava_url, "sarkandaugava_01_12_21.xlsx")
sarkan_df
# Out:
# Last page is 2
# Gathering data from https://www.ss.com/lv/real-estate/flats/riga/sarkandaugava/hand_over/
# Gathering data from https://www.ss.com/lv/real-estate/flats/riga/sarkandaugava/hand_over/page2.html
#                                           description  ...         Cena
# 0   Saimniece izīrē divistaba dzīvokli ar malkas a...  ...  240  €/mēn.
# 1   Сдается однокомнатная квартира со всеми удобст...  ...  220  €/mēn.
# 2   Квартира в сталинском доме, высокий первый эта...  ...  300  €/mēn.
# 3   Izīrē dzīvokli ar visām ērtībām, tehniku, dīvā...  ...  250  €/mēn.
# 4   Izīrē ērtu dzīvokli ar remontu un mēbelēm. Krā...  ...  160  €/mēn.
# 5   Владелец сдаёт мебелированную, со всеми удобст...  ...  280  €/mēn.
# 6   Tikko pēc kosmētiska remonta. Istabas caurstai...  ...  320  €/mēn.
# 7   Izīrē 2istabu dzīvokli Sarkandaugavā, Limbažu ...  ...  200  €/mēn.
# 8   Izīrēju divistaba dzīvokli ar daļējām ērtībām ...  ...  180  €/mēn.
# ...

# %% [markdown]
# # TODO
# # Try with different starting address not only centrs
# ## Maybe combine regions
# ## See how it would work with maybe cars
# ## Data engineering make new columns based on existing ones, clean some columns
# ### Changing floors 2/6 to columns 2 and 6, clean up Euro signs
# ## Sorting, Describing, Grouping by regions etc

# %%
df = pd.read_excel("centrs_25_11.xlsx")
df.head()

# %%
df["price"] = df.Cena.str.split(' ').str[0]
df.head()

# %%
df.price = df.price.str.replace(",","").astype('int32')
df.head()

# %%
df.price.hist()

# %%
df[['Floor','MaxFloor']] = df.Stāvs.str.split("/",expand=True)
df.info()

# %%
#typecasting example
df.Floor = df.Floor.astype('int32')
df.MaxFloor = df.MaxFloor.astype('int32')

# %%
df.describe().T # T is for transposing rows and columns

# %%
df.describe().T.to_csv("center_stats.csv")

# %%
import plotly.express as px

# %%
fig = px.histogram(df, x="price")
fig.show()

# %%
import seaborn as sns # seaborn sits on top of matplotlib with better defaults
import matplotlib.pyplot as plt

# %%
# Basic correlogram
sns.pairplot(df)

# %%
# Basic correlogram
sns.pairplot(df)

# %%
volvo_url = "https://www.ss.com/lv/transport/cars/volvo/sell/"
gr_auto = df.groupby(["Gads","Modelis"])["Cena"].agg(["min", "max", "mean"])  #.head(n = 10)

# %%
print(dt.today())

# %%
suzuki_url = "https://www.ss.com/lv/transport/cars/suzuki/"
# sdf = get_all_ads_df(suzuki_url, f"suzuki_{dt.today()}.xlsx")
sdf = get_all_ads_df(suzuki_url, f"suzuki.xlsx")
sdf.head()

# %%
sdf.info()

# %%
sdf["Tilp."] = sdf["Tilp."].str.replace("\w","", regex=True)
sdf.head()

# %%
sdf["Nobrauk."] = sdf["Nobrauk."].str.replace("\D","", regex=True) # so no digits removed
sdf.head()

# %%
sdf["Cena"] = sdf["Cena"].str.replace("\D","", regex=True) # so no digits removed
sdf.head()

# %%
sdf = sdf.dropna(how="any", axis=0)
sdf

# %%
sdf = sdf[sdf["Nobrauk."].str.len() > 0] # got rid of those empty rows finally
sdf

# %%
sdf["Cena"] = sdf["Cena"].astype("float32")

# %%
gr_auto = sdf.groupby(["Gads","Modelis"])["Cena"].agg(["count","min", "max", "mean"])
gr_auto

# %% [markdown]
# ## Selenium drivers for when Beatiful Soup down not wok
#
# SOmetimes pages are not static, (especially if the page is not fully built).. Then you would use Selenium.
#
# ### Selenium Drivers for Python
#
# In case of Selenium you need to install Selenium itself and also drivers for a particular Web Browser.
#
# So if you are using Chrome you owuld install drivers for Chrome.
#
# So Selenium gets past other pages which are stricter for requiring Javascript and CSS and so on.
#
# https://www.selenium.dev/selenium/docs/api/py/
