# %% [markdown]
# # 📊 Pandas pamati (Google Colab) — uzdevums
#
# ## 🎯 Mērķis
# Iemācīties ielādēt, apskatīt, filtrēt un apkopot tabulārus datus, izmantojot **pandas**.
#
# Šajā darbā tu:
# - izveidosi/ielādēsi datu kopu kā `DataFrame`
# - izpētīsi datu struktūru un tipu informāciju
# - atlasīsi kolonnas un rindas
# - filtrēsi datus ar nosacījumiem
# - aprēķināsi pamatstatistiku un kopsavilkumus
# - izveidosi atvasinātu kolonnu
#
# > **Darba ilgums:** ~60–90 min
# > **Vide:** Google Colab

# %% [markdown]
# ## 1️⃣ Sagatavošanās
#
# ### 📌 Uzdevums
# Importē **pandas**.

# %%
import pandas as pd

# %% [markdown]
# ## 2️⃣ Datu kopas izveide
#
# ### 📌 Uzdevums
# Izveido `DataFrame` no dotajiem datiem. (Šai laboratorijai nav vajadzīgas ārējas lejupielādes.)

# %%
data = {
    "student_id": [101, 102, 103, 104, 105, 106],
    "name": ["Anna", "Jānis", "Laura", "Mārtiņš", "Elīna", "Tomass"],
    "course": ["Python", "Python", "Data Science", "Python", "Data Science", "Python"],
    "age": [19, 21, 20, 22, 19, 23],
    "exam_score": [85, 72, 91, 68, 88, 77]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# ## 3️⃣ Datu apskate (inspekcija)
#
# ### 📌 Uzdevumi
# Izpildi sekojošo, izmantojot pandas komandas (nevis ar roku):
#
# 1. Parādi **pirmās 3 rindas**
# 2. Parādi **pēdējās 2 rindas**
# 3. Parādi **kolonnu nosaukumus**
# 4. Parādi **datu tipus**
# 5. Parādi **pamatstatistiku** (skaitliskajām kolonnām)
#
# ✏️ **Ieraksti komandas zemāk norādītajās šūnās.**

# %%
# 1) Pirmās 3 rindas
# Tava atbilde šeit

# %%
# 2) Pēdējās 2 rindas
# Tava atbilde šeit

# %%
# 3) Kolonnu nosaukumi
# Tava atbilde šeit

# %%
# 4) Datu tipi / kopsavilkums
# Tava atbilde šeit

# %%
# 5) Pamatstatistika
# Tava atbilde šeit

# %% [markdown]
# ## 4️⃣ Kolonnu atlase
#
# ### 📌 Uzdevumi
# 1. Atlasiet tikai kolonnas `name` un `exam_score`
# 2. Saglabā rezultātu mainīgajā `scores_df`

# %%
# Tava atbilde šeit

# %% [markdown]
# ## 5️⃣ Rindu filtrēšana
#
# ### 📌 Uzdevumi
# Izmanto filtrēšanu ar nosacījumiem:
#
# 1. Atlasīt studentus, kuri ieguva **80 vai vairāk**
# 2. Atlasīt studentus, kuri ir **vecāki par 20**
# 3. Atlasīt studentus, kuri ir kursā **Python** **un** ieguva vismaz **75**
#
# > Padoms: izmanto loģiskos operatorus `&`, `|` un iekavas.

# %%
# 1) exam_score >= 80
# Tava atbilde šeit

# %%
# 2) age > 20
# Tava atbilde šeit

# %%
# 3) course == "Python" un exam_score >= 75
# Tava atbilde šeit

# %% [markdown]
# ## 6️⃣ Datu kārtošana (sorting)
#
# ### 📌 Uzdevumi
# 1. Sakārto studentus pēc `exam_score` (no lielākā uz mazāko)
# 2. Sakārto studentus pēc `age` (no jaunākā uz vecāko)

# %%
# 1) Pēc exam_score dilstoši
# Tava atbilde šeit

# %%
# 2) Pēc age augoši
# Tava atbilde šeit

# %% [markdown]
# ## 7️⃣ Vienkāršas apkopošanas (aggregations)
#
# ### 📌 Uzdevumi
# 1. Aprēķini **vidējo eksāmena rezultātu**
# 2. Atrodi **minimālo** un **maksimālo** eksāmena rezultātu
# 3. Saskaiti, cik studentu ir katrā kursā (`course`)

# %%
# 1) Vidējais exam_score
# Tava atbilde šeit

# %%
# 2) Min un max exam_score
# Tava atbilde šeit

# %%
# 3) Studentu skaits katrā kursā
# Tava atbilde šeit

# %% [markdown]
# ## 8️⃣ Grupēšana (`groupby`)
#
# ### 📌 Uzdevumi
# 1. Aprēķini **vidējo exam_score katram kursam**
# 2. Aprēķini **studentu skaitu katram kursam**
#
# > Padoms: `df.groupby("course")["exam_score"].mean()` ir labs sākums.

# %%
# 1) Vidējais exam_score pa kursiem
# Tava atbilde šeit

# %%
# 2) Studentu skaits pa kursiem
# Tava atbilde šeit

# %% [markdown]
# ## 9️⃣ Jaunas kolonnas izveide
#
# ### 📌 Uzdevums
# Pievieno jaunu kolonnu `passed`:
# - `True`, ja `exam_score` ≥ 75
# - `False`, ja citādi
#
# 📌 Padoms: vari izmantot loģisku izteiksmi tieši kā kolonnu.

# %%
# Tava atbilde šeit

# %% [markdown]
# ## 🔟 Bonuss (pēc izvēles)
#
# ### 📌 Papildu uzdevumi
# 1. Pievieno kolonnu `grade`:
#    - `"A"` ja ≥ 90
#    - `"B"` ja ≥ 80
#    - `"C"` ja ≥ 70
#    - `"D"` citādi
# 2. Parādi tikai tos studentus, kuri **nenokārtoja** (`passed == False`)
# 3. Eksportē gala `DataFrame` uz CSV failu
#
# > Bonuss nav obligāts, bet ir labs treniņš.

# %%
# 1) grade kolonna
# Tava atbilde šeit

# %%
# 2) Tikai nenokārtojušie
# Tava atbilde šeit

# %%
# 3) Eksports uz CSV
# Tava atbilde šeit

# %% [markdown]
# ## 📤 Iesniegšana
#
# Iesniedz:
# - Aizpildītu Colab/Jupyter piezīmju grāmatiņu (`.ipynb`)
# - Lai **visas šūnas ir izpildītas** (redzami rezultāti)
# - Saprotamus mainīgo nosaukumus
# - Bez liekiem `print()`, ja tas nav nepieciešams
#
# ## ✅ Ko šis uzdevums pārbauda
# - DataFrame izveidi/ielādi
# - `.head()`, `.tail()`, `.info()`, `.describe()`
# - kolonnu un rindu atlasi
# - filtrēšanu ar nosacījumiem
# - kārtošanu
# - apkopošanu un `groupby`
# - jaunu kolonnu izveidi
